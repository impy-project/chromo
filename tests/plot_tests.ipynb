# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from misc_test_func import *

# %% [markdown]
# Test center of mass pseudo-rapidity
# ----------------------------------

# %%
xgrid, yval_d = pickle.load(open('test_all_cms.pkl'))
f, axes = plt.subplots(1,1,figsize=(8,6))

x_centers = 0.5*(xgrid[1:] + xgrid[:-1])
[axes.plot(x_centers,yval_d[k],axes=axes, label=k) for k in yval_d]
plt.legend(ncol=3)
plt.xlim(min(xgrid),max(xgrid))
plt.ylim(0, 1.4*max([max(yval_d[k]) for k in yval_d]))
# Out:
# (0, 3.9227999999998406)

# %%
xgrid, yval_d = pickle.load(open('test_all_lab.pkl'))
f, axes = plt.subplots(1,1,figsize=(8,6))

x_centers = 0.5*(xgrid[1:] + xgrid[:-1])
[axes.plot(x_centers,yval_d[k],axes=axes, label=k) for k in yval_d]
plt.legend(ncol=3)
plt.xlim(min(xgrid),max(xgrid))
plt.ylim(0, 1.4*max([max(yval_d[k]) for k in yval_d]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c0649ec30627> in <module>()
#       6 plt.legend(ncol=3)
#       7 plt.xlim(min(xgrid),max(xgrid))
# ----> 8 plt.ylim(0, 1.4*max([max(yval_d[k]) for k in yval_d]))
#
# /home/users/afedynitch/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in ylim(*args, **kwargs)
#    1588     if not args and not kwargs:
#    1589         return ax.get_ylim()
# -> 1590     ret = ax.set_ylim(*args, **kwargs)
#    1591     return ret
#    1592
#
# /home/users/afedynitch/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_ylim(self, bottom, top, emit, auto, **kw)
#    3456
#    3457         bottom = self._validate_converted_limits(bottom, self.convert_yunits)
# -> 3458         top = self._validate_converted_limits(top, self.convert_yunits)
#    3459
#    3460         old_bottom, old_top = self.get_ylim()
#
# /home/users/afedynitch/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _validate_converted_limits(self, limit, convert)
#    3066                     (not np.isreal(converted_limit) or
#    3067                         not np.isfinite(converted_limit))):
# -> 3068                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3069             return converted_limit
#    3070
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
yval_d
# Out:
# {'DPMJETIII171': array([0.00847249, 0.01379401, 0.01556037, 0.01425373, 0.01393802,
#         0.01413925, 0.01392709, 0.01154003, 0.01258055, 0.01415062,
#         0.01164026, 0.01132591, 0.00894019, 0.00752118, 0.00800986,
#         0.00651091, 0.00591207, 0.00492164, 0.0076598 , 0.01667731]),
#  'EPOSLHC': array([0.00883025, 0.01288286, 0.01284515, 0.01245292, 0.01150982,
#         0.01116446, 0.01081788, 0.01085622, 0.01100092, 0.01079476,
#         0.0106822 , 0.01164482, 0.01210693, 0.01453131, 0.01250906,
#         0.0128158 , 0.01046969, 0.0152388 , 0.01642694, 0.04167001]),
#  'PYTHIA8': array([0.00783245, 0.02437779, 0.01497319, 0.01411871, 0.01327549,
#         0.01271951, 0.0117775 , 0.009515  , 0.00920491, 0.00935912,
#         0.00963943, 0.00770644, 0.00610806, 0.00620342, 0.00518323,
#         0.00910474, 0.00749946, 0.00937881, 0.01914856, 0.07666662]),
#  'QGSJET01C': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan]),
#  'QGSJETII03': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan]),
#  'QGSJETII04': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan]),
#  'URQMD34': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan])}
