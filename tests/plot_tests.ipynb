# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from misc_test_func import *

# %% [markdown]
# Test center of mass pseudo-rapidity
# ----------------------------------

# %%
xgrid, yval_d = pickle.load(open('test_all_cms.pkl'))
f, axes = plt.subplots(1,1,figsize=(8,6))

x_centers = 0.5*(xgrid[1:] + xgrid[:-1])
[axes.plot(x_centers,yval_d[k],axes=axes, label=k) for k in yval_d]
plt.legend(ncol=3)
plt.xlim(min(xgrid),max(xgrid))
plt.ylim(0, 1.4*max([max(yval_d[k]) for k in yval_d]))
# Out:
# (0, 7.801080000000259)

# %%
xgrid, yval_d_p, yval_d_pi = pickle.load(open('test_all_lab.pkl'))
f, axes = plt.subplots(1,1,figsize=(8,6))

x_centers = 0.5*(xgrid[1:] + xgrid[:-1])
[axes.plot(x_centers,yval_d[k],axes=axes, label=k) for k in yval_d]
plt.legend(ncol=3)
plt.xlim(min(xgrid),max(xgrid))
plt.ylim(0, 1.4*max([max(yval_d[k]) for k in yval_d]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-fd7831cd80b9> in <module>()
# ----> 1 xgrid, yval_d_p, yval_d_pi = pickle.load(open('test_all_lab.pkl'))
#       2 f, axes = plt.subplots(1,1,figsize=(8,6))
#       3
#       4 x_centers = 0.5*(xgrid[1:] + xgrid[:-1])
#       5 [axes.plot(x_centers,yval_d[k],axes=axes, label=k) for k in yval_d]
#
# ValueError: need more than 2 values to unpack

# %%
pickle.load(open('test_all_lab.pkl'))
# Out:
# (array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  {'DPMJETIII171': array([0.00835226, 0.01383797, 0.01459854, 0.01467589, 0.01441684,
#          0.01388181, 0.01477239, 0.01259949, 0.01198467, 0.01383516,
#          0.01052267, 0.0110004 , 0.01123868, 0.0089018 , 0.00785903,
#          0.00737798, 0.00751544, 0.0049385 , 0.00617361, 0.01815714]),
#   'DPMJETIII306': array([0.00794904, 0.01331439, 0.01465054, 0.01520859, 0.01432005,
#          0.01393518, 0.01315596, 0.01217055, 0.01282041, 0.01186233,
#          0.01196929, 0.00998256, 0.01131384, 0.00958682, 0.00983467,
#          0.00756   , 0.00518891, 0.00685929, 0.00827856, 0.0205695 ]),
#   'EPOSLHC': array([0.00882514, 0.01288961, 0.01324765, 0.01238038, 0.01181961,
#          0.01103641, 0.01083482, 0.00914356, 0.01198996, 0.01154568,
#          0.01229595, 0.01322173, 0.0120741 , 0.01189071, 0.01282779,
#          0.01235187, 0.013239  , 0.01195708, 0.01799946, 0.03664493]),
#   'PYTHIA8': array([0.00806204, 0.02449094, 0.01494051, 0.0149535 , 0.01308322,
#          0.01084473, 0.01136427, 0.00927247, 0.00969206, 0.00868272,
#          0.00807787, 0.00703976, 0.00608949, 0.00622498, 0.00507784,
#          0.00722703, 0.00848362, 0.00881352, 0.0179722 , 0.08854473]),
#   'QGSJET01C': array([0.00939936, 0.01416732, 0.01348222, 0.01226218, 0.01100673,
#          0.0096219 , 0.00952759, 0.00900147, 0.00778788, 0.00858059,
#          0.00771409, 0.00965231, 0.00959279, 0.00931053, 0.01103295,
#          0.00950337, 0.01456267, 0.01499256, 0.02005073, 0.02986614]),
#   'QGSJETII03': array([0.00809548, 0.01394233, 0.01385431, 0.01340284, 0.01201703,
#          0.0110626 , 0.01037388, 0.00994892, 0.01016264, 0.00974541,
#          0.0101914 , 0.00959279, 0.01041679, 0.01159026, 0.01398904,
#          0.01304376, 0.01324001, 0.01311657, 0.02069917, 0.03027127]),
#   'QGSJETII04': array([0.00768264, 0.01329201, 0.01342454, 0.01228256, 0.01218069,
#          0.01222888, 0.00929184, 0.00948575, 0.01193087, 0.00993382,
#          0.01089003, 0.01216273, 0.01251699, 0.01364938, 0.01142385,
#          0.01431064, 0.01272243, 0.01489908, 0.01799473, 0.02864898]),
#   'SIBYLL21': array([0.00711368, 0.01103303, 0.01077234, 0.0110087 , 0.01223733,
#          0.01213805, 0.01154297, 0.01334421, 0.01358435, 0.01397802,
#          0.01492124, 0.01804355, 0.01565412, 0.01816504, 0.01666104,
#          0.01456179, 0.02069171, 0.01618725, 0.01796733, 0.06159085]),
#   'SIBYLL23': array([0.00700068, 0.01234345, 0.01309313, 0.01279017, 0.01221123,
#          0.01169249, 0.0133699 , 0.01330535, 0.01112352, 0.01012615,
#          0.00915193, 0.01103632, 0.01053526, 0.00951816, 0.0125313 ,
#          0.01070734, 0.01109139, 0.01065971, 0.01476894, 0.05388124]),
#   'SIBYLL23C': array([0.00760153, 0.0124802 , 0.01300339, 0.01298489, 0.01251699,
#          0.01245515, 0.01226879, 0.01154743, 0.01146807, 0.01122568,
#          0.0110971 , 0.01131434, 0.00996816, 0.00846622, 0.0117958 ,
#          0.00893067, 0.01177662, 0.01500325, 0.01331924, 0.04766284])})
