# %%
import urllib.request as request
import re

url = "https://www.pythia.org/latest-manual"
r = request.urlopen(url)
assert r.status == 200
data1 = r.read().decode()

# %%
html = []
for href in re.findall('href="([^"]+\.html)"', data1):
    print(href)
    r = request.urlopen(f"{url}/{href}")
    assert r.status == 200
    d = r.read().decode()
    html.append((href, d))
# Out:
# AdvancedUsage.html
# AlpgenEventInterface.html
# BeamParameters.html
# BeamRemnants.html
# BeamShape.html
# Bibliography.html
# BoseEinsteinEffects.html
# CKKWLMerging.html
# ColourReconnection.html
# CompositenessProcesses.html
# CouplingsAndScales.html
# CrossSectionsAndWeights.html
# DarkMatterProcesses.html
# DeuteronProduction.html
# Diffraction.html
# DireExpert.html
# DireShowers.html
# DireWeights.html
# ElectroweakProcesses.html
# ErrorChecks.html
# EventAnalysis.html
# EventInformation.html
# EventRecord.html
# EventStatistics.html
# ExampleKeywords.html
# ExternalDecays.html
# ExtraDimensionalProcesses.html
# FlavourSelection.html
# FourVectors.html
# FourthGenerationProcesses.html
# Fragmentation.html
# Frontpage.html
# GettingStarted.html
# Glossary.html
# HadronLevelStandalone.html
# HadronVertexInformation.html
# HadronWidths.html
# HadronicRescattering.html
# HeavyIons.html
# HelacOniaProcesses.html
# HepMCInterface.html
# HiddenValleyProcesses.html
# HiggsProcesses.html
# Histograms.html
# ImplementNewMatching.html
# ImplementNewShowers.html
# Index.html
# JetFinders.html
# JetMatching.html
# LHA.html
# LHAHDF5.html
# LHEF.html
# LeftRightSymmetryProcesses.html
# LeptoquarkProcesses.html
# MadGraph5Processes.html
# MainProgramSettings.html
# MasterSwitches.html
# MatchingAndMerging.html
# MergingVariations.html
# MultipartonInteractions.html
# NLOMerging.html
# NewGaugeBosonProcesses.html
# OniaProcesses.html
# PDFSelection.html
# POWHEGMerging.html
# Parallelism.html
# ParticleData.html
# ParticleDataScheme.html
# ParticleDecays.html
# ParticleProperties.html
# PartonDistributions.html
# PartonShowers.html
# PartonVertexInformation.html
# PhaseSpaceCuts.html
# Photoproduction.html
# ProMCFiles.html
# ProcessSelection.html
# ProgramClasses.html
# ProgramFiles.html
# ProgramFlow.html
# ProgramMethods.html
# PythonInterface.html
# QCDHardProcesses.html
# QCDLowEnergyProcesses.html
# QCDSoftProcesses.html
# RHadrons.html
# RIVETusage.html
# ROOTusage.html
# RandomNumberSeed.html
# RandomNumbers.html
# ResonanceDecays.html
# RopeHadronization.html
# SUSYLesHouchesAccord.html
# SUSYProcesses.html
# SampleMainPrograms.html
# SaveSettings.html
# SecondHardProcess.html
# SemiInternalProcesses.html
# SemiInternalResonances.html
# SettingsScheme.html
# SimpleShowers.html
# SpacelikeShowers.html
# StandardModelParameters.html
# TimelikeShowers.html
# TopProcesses.html
# TotalCrossSections.html
# Tunes.html
# UMEPSMerging.html
# UpdateHistory.html
# UserHooks.html
# Variations.html
# Version.html
# Vincia.html
# VinciaEW.html
# VinciaMECs.html
# VinciaMerging.html
# VinciaQCD.html
# WeakShowers.html
# Welcome.html
# aMCatNLOMatching.html

# %%
parms = {}
for href, page in html:
    parms[href] = re.findall("<code>parm <\/code><strong> (.+?) <\/strong> \n \(<code>default = <strong>*(.+?)<\/strong><\/code>(?:; <code>minimum = (.+?)<\/code>)?(?:; <code>maximum = (.+?)<\/code>)?", page.replace("&nbsp;", ""))

# %%
import json

with open("parms.json", "w") as f:
    json.dump(parms, f)

# %% [markdown]
# Some modes need to be set so that certain tuning parameters have an effect:
#
# ```
# ColourReconnection:mode = 1
# ColourReconnection:allowDoubleJunRem = off
# Ropewalk:RopeHadronization = on
# Ropewalk:doShoving = on
# Ropewalk:doFlavour = on
# HadronLevel:BoseEinstein = on
# ContactInteractions:QCqq2qq = on
# ContactInteractions:QCqqbar2qqbar = on
# SigmaDiffractive:PomFlux = on
# Diffraction:doHard = on
# # needed for hadronic rescattering
# Fragmentation:setVertices = on
# ```

# %%
ignored = {
    "Beams:",
    "Higgs",
    "Check",
    "Main",
    "BeamRemnants:aRemnantBaryon",
    "BeamRemnants:bRemnantBaryon",
    "ColourReconnection:range",
    "Merging:",
    "ColourReconnection:m2Lambda",
    "ColourReconnection:fracGluon",
    "ColourReconnection:dLambdaCut",
    "ColourReconnection:kI",
    "ColourReconnection:fragmentationTime" "ColourReconnection:rHadron",
    "ColourReconnection:blow",
    "ExcitedFermion",
    "ContactInteractions",
    "SigmaProcess:renorm",
    "SigmaProcess:factor",
    "DM:",
    "Sdm:",
    "Zp:",
    "DeuteronProduction:",
    "Dire",
    "StringZ:avgZLund",
    # requires StringPT:thermalModel = on
    "StringPT:temperature",
    "StringPT:tempPreFactor",
    # "should not be touched"
    "StringFragmentation:stop",
    "HadronVertex:intermediateTau0",
    "Rescattering:boost",
    # only for SigmaTotal:mode = 0
    "SigmaTotal:sigma",
    "SigmaElastic:bSlope",
    "SigmaElastic:rho",
    # if we changed these parameters, we would need to ensure unitarity
    "StandardModel:V"
}

filtered = {}
for href, pl in parms.items():
    if href in {
        "DireExpert.html",
        "DireShowers.html",
        "DireWeights.html",
        "ExtraDimensionalProcesses.html",
        "FourthGenerationProcesses.html",
        "HiddenValleyProcesses.html",
        "JetMatching.html",
        "LeftRightSymmetryProcesses.html",
        "LeptoquarkProcesses.html",
        "LHEF.html",
        "LeftRightSymmetryProcesses.html",
        "SUSYLesHouchesAccord.html"
        "SecondHardProcess.html",
        "SpacelikeShowers.html",
        "TimelikeShowers.html",
        "Variations.html",
        "Version.html",
        "WeakShowers.html",
        "NewGaugeBosonProcesses.html",
    }:
        continue
    pl2 = []
    for parm, vdef, vmin, vmax in pl:
        skip = False
        for ig in ignored:
            if parm.startswith(ig):
                skip = True
                break
        if skip:
            continue
        pl2.append((parm, vdef, vmin, vmax))
    if pl2:
        filtered[href] = pl2

for href in filtered:
    print(href)
    for p in filtered[href]:
        print(p)
# Out:
# BeamRemnants.html
# ('BeamRemnants:primordialKTsoft', '0.9', '0.', '')
# ('BeamRemnants:primordialKThard', '1.8', '0.', '')
# ('BeamRemnants:halfScaleForKT', '1.5', '0.', '')
# ('BeamRemnants:halfMassForKT', '1.', '0.', '')
# ('BeamRemnants:reducedKTatHighY', '0.5', '0.', '1.')
# ('BeamRemnants:primordialKTremnant', '0.4', '0.', '')
# ('BeamRemnants:saturation', '5', '0.1', '100000')
# ('BeamRemnants:valencePowerMeson', '0.8', '0.', '')
# ('BeamRemnants:valencePowerUinP', '3.5', '0.', '')
# ('BeamRemnants:valencePowerDinP', '2.0', '0.', '')
# ('BeamRemnants:valenceDiqEnhance', '2.0', '0.5', '10.')
# ('BeamRemnants:gluonPower', '4.0', '0.', '')
# ('BeamRemnants:xGluonCutoff', '1E-7', '1E-10', '1')
# ('BeamRemnants:dampPopcorn', '1.', '0.', '1.')
# BoseEinsteinEffects.html
# ('BoseEinstein:lambda', '1.', '0.', '2.')
# ('BoseEinstein:QRef', '0.2', '0.05', '1.')
# ('BoseEinstein:widthSep', '0.02', '0.001', '1.')
# ColourReconnection.html
# ('ColourReconnection:m0', '0.3', '0.1', '5.')
# ('ColourReconnection:junctionCorrection', '1.20', '0.01', '10.')
# ('ColourReconnection:timeDilationPar', '0.18', '0', '100')
# ('ColourReconnection:fragmentationTime', '1.5', '1.', '2.')
# ('ColourReconnection:rHadron', '0.5', '0.3', '1.')
# CouplingsAndScales.html
# ('SigmaProcess:alphaSvalue', '0.13', '0.06', '0.25')
# ('SigmaProcess:Kfactor', '1.0', '0.5', '4.0')
# Diffraction.html
# ('Diffraction:mMinPert', '10.', '5.', '')
# ('Diffraction:mWidthPert', '10.', '1.', '')
# ('Diffraction:probMaxPert', '1.', '0.', '1.')
# ('Diffraction:pickQuarkNorm', '5.0', '0.', '')
# ('Diffraction:pickQuarkPower', '1.0', '', '')
# ('Diffraction:primKTwidth', '0.5', '0.', '')
# ('Diffraction:largeMassSuppress', '4.', '0.', '')
# ('Diffraction:sigmaRefPomP', '10.', '2.', '40.')
# ('Diffraction:mRefPomP', '100.0', '1.', '')
# ('Diffraction:mPowPomP', '0.0', '0.0', '0.5')
# ('Diffraction:coreRadius', '0.4', '0.1', '1.')
# ('Diffraction:coreFraction', '0.5', '0.', '1.')
# ('Diffraction:expPow', '1.', '0.4', '10.')
# ('Diffraction:PomFluxRescale', '1.0', '0.2', '2.0')
# FlavourSelection.html
# ('StringFlav:probStoUD', '0.217', '0.0', '1.0')
# ('StringFlav:probQQtoQ', '0.081', '0.0', '1.0')
# ('StringFlav:probSQtoQQ', '0.915', '0.0', '1.0')
# ('StringFlav:probQQ1toQQ0', '0.0275', '0.0', '1.0')
# ('StringFlav:mesonUDvector', '0.50', '0.', '3.')
# ('StringFlav:mesonSvector', '0.55', '0.', '3.')
# ('StringFlav:mesonCvector', '0.88', '0.', '3.')
# ('StringFlav:mesonBvector', '2.20', '0.', '3.')
# ('StringFlav:thetaPS', '-15.', '-90.', '90.')
# ('StringFlav:thetaV', '36.', '-90.', '90.')
# ('StringFlav:etaSup', '0.60', '0.', '1.')
# ('StringFlav:etaPrimeSup', '0.12', '0.', '1.')
# ('StringFlav:mesonUDL1S0J1', '0.0', '0.', '3.')
# ('StringFlav:mesonUDL1S1J0', '0.0', '0.', '1.')
# ('StringFlav:mesonUDL1S1J1', '0.0', '0.', '3.')
# ('StringFlav:mesonUDL1S1J2', '0.0', '0.', '5.')
# ('StringFlav:mesonSL1S0J1', '0.0', '0.', '3.')
# ('StringFlav:mesonSL1S1J0', '0.0', '0.', '1.')
# ('StringFlav:mesonSL1S1J1', '0.0', '0.', '3.')
# ('StringFlav:mesonSL1S1J2', '0.0', '0.', '5.')
# ('StringFlav:mesonCL1S0J1', '0.0', '0.', '3.')
# ('StringFlav:mesonCL1S1J0', '0.0', '0.', '1.')
# ('StringFlav:mesonCL1S1J1', '0.0', '0.', '3.')
# ('StringFlav:mesonCL1S1J2', '0.0', '0.', '5.')
# ('StringFlav:mesonBL1S0J1', '0.0', '0.', '3.')
# ('StringFlav:mesonBL1S1J0', '0.0', '0.', '1.')
# ('StringFlav:mesonBL1S1J1', '0.0', '0.', '3.')
# ('StringFlav:mesonBL1S1J2', '0.0', '0.', '5.')
# ('StringFlav:thetaL1S0J1', '35.3', '-90.', '90.')
# ('StringFlav:thetaL1S1J0', '35.3', '-90.', '90.')
# ('StringFlav:thetaL1S1J1', '35.3', '-90.', '90.')
# ('StringFlav:thetaL1S1J2', '28.0', '-90.', '90.')
# ('StringFlav:decupletSup', '1.0', '0.0', '1.0')
# ('StringFlav:popcornRate', '0.5', '0.', '2.0')
# ('StringFlav:popcornSpair', '0.9', '0.', '1.0')
# ('StringFlav:popcornSmeson', '0.5', '0.', '1.0')
# ('StringFlav:lightLeadingBSup', '0.5', '0.', '1.0')
# ('StringFlav:heavyLeadingBSup', '0.9', '0.', '1.0')
# ('StringFlav:BtoMratio', '0.357', '0.1', '10.0')
# ('StringFlav:StrangeSuppression', '0.5', '0.01', '1.0')
# Fragmentation.html
# ('StringZ:aLund', '0.68', '0.0', '2.0')
# ('StringZ:bLund', '0.98', '0.2', '2.0')
# ('StringZ:aExtraSQuark', '0.0', '0.0', '2.0')
# ('StringZ:aExtraDiquark', '0.97', '0.0', '2.0')
# ('StringZ:rFactC', '1.32', '0.0', '2.0')
# ('StringZ:rFactB', '0.855', '0.0', '2.0')
# ('StringZ:rFactH', '1.0', '0.0', '2.0')
# ('StringZ:aNonstandardC', '0.3', '0.0', '2.0')
# ('StringZ:aNonstandardB', '0.3', '0.0', '2.0')
# ('StringZ:aNonstandardH', '0.3', '0.0', '2.0')
# ('StringZ:bNonstandardC', '0.8', '0.2', '2.0')
# ('StringZ:bNonstandardB', '0.8', '0.2', '2.0')
# ('StringZ:bNonstandardH', '0.8', '0.2', '2.0')
# ('StringZ:epsilonC', '0.05', '0.01', '0.25')
# ('StringZ:epsilonB', '0.005', '0.001', '0.025')
# ('StringZ:epsilonH', '0.005', '0.0001', '0.25')
# ('StringPT:sigma', '0.335', '0.0', '1.0')
# ('StringPT:enhancedFraction', '0.01', '0.0', '1.')
# ('StringPT:enhancedWidth', '2.0', '1.0', '10.0')
# ('StringPT:widthPreStrange', '1.0', '1.0', '10.0')
# ('StringPT:widthPreDiquark', '1.0', '1.0', '10.0')
# ('StringPT:expMPI', '0.0', '0.0', '1.0')
# ('StringPT:expNSP', '0.13', '0.0', '1.0')
# ('HadronLevel:mStringMin', '1.', '0.5', '1.5')
# ('FragmentationSystems:mJoin', '0.3', '0.2', '1.')
# ('FragmentationSystems:mJoinJunction', '1.0', '0.5', '2.')
# ('StringFragmentation:eNormJunction', '2.0', '0.5', '10')
# ('StringFragmentation:eBothLeftJunction', '1.0', '0.5', '')
# ('StringFragmentation:eMaxLeftJunction', '10.0', '0.', '')
# ('StringFragmentation:eMinLeftJunction', '0.2', '0.', '')
# HadronVertexInformation.html
# ('HadronVertex:kappa', '1.', '0.5', '10.')
# ('HadronVertex:xySmear', '0.5', '0.', '2.')
# ('HadronVertex:maxSmear', '0.2', '0.', '10.')
# ('HadronVertex:maxTau', '40.', '1.', '100.')
# HadronicRescattering.html
# ('Rescattering:opacity', '0.9', '0.', '1.')
# ('Rescattering:bMax', '5.', '0.', '100.')
# ('Rescattering:tau0RapidDecay', '100.', '10.', '')
# ('Rescattering:tauRegeneration', '1.', '0.', '2.')
# HeavyIons.html
# ('HeavyIon:bWidth', '0.0', '0.0', '')
# ('HeavyIonA:WSR', '0.0', '0.0', '')
# ('HeavyIonB:WSR', '0.0', '0.0', '')
# ('HeavyIonA:WSa', '0.0', '0.0', '')
# ('HeavyIonB:WSa', '0.0', '0.0', '')
# ('HeavyIonA:HONuclearChargeRadius', '0.0', '0.0', '')
# ('HeavyIonB:HONuclearChargeRadius', '0.0', '0.0', '')
# ('HeavyIonA:HOProtonChargeRadius', '0.7714', '0.0', '')
# ('HeavyIonB:HOProtonChargeRadius', '0.7714', '0.0', '')
# ('HeavyIonA:GaussianChargeRadius', '7.7', '0.0', '')
# ('HeavyIonB:GaussianChargeRadius', '7.7', '0.0', '')
# ('HeavyIonA:HulthenA', '0.4', '0.0', '')
# ('HeavyIonB:HulthenA', '0.4', '0.0', '')
# ('HeavyIonA:HulthenB', '1.2', '0.0', '')
# ('HeavyIonB:HulthenB', '1.2', '0.0', '')
# ('HeavyIonA:HardCoreRadius', '0.9', '0.0', '')
# ('HeavyIonB:HardCoreRadius', '0.9', '0.0', '')
# ('HeavyIon:SigFitFuzz', '0.2', '0.0', '0.5')
# ('Angantyr:impactFudge', '0.85', '0.0', '4.0')
# ('Angantyr:SDTestB', '-1.0', '', '')
# MultipartonInteractions.html
# ('MultipartonInteractions:alphaSvalue', '0.130', '0.06', '0.25')
# ('MultipartonInteractions:Kfactor', '1.0', '0.5', '4.0')
# ('MultipartonInteractions:pT0Ref', '2.28', '0.5', '10.0')
# ('MultipartonInteractions:ecmRef', '7000.0', '1.', '')
# ('MultipartonInteractions:ecmPow', '0.215', '0.0', '0.5')
# ('MultipartonInteractions:pTmin', '0.2', '0.1', '10.0')
# ('MultipartonInteractions:coreRadius', '0.4', '0.1', '1.')
# ('MultipartonInteractions:coreFraction', '0.5', '0.', '1.')
# ('MultipartonInteractions:expPow', '1.85', '0.4', '10.')
# ('MultipartonInteractions:a1', '0.15', '0.', '2.')
# ('MultipartonInteractions:ySepRescatter', '0.', '', '')
# ('MultipartonInteractions:deltaYRescatter', '1.', '0.1', '')
# OniaProcesses.html
# ('Onia:massSplit', '0.2', '0.0', '1.0')
# PDFSelection.html
# ('PDF:PomGluonA', '0.', '-0.5', '2.')
# ('PDF:PomGluonB', '3.', '0.', '10.')
# ('PDF:PomQuarkA', '0.', '-0.5', '2.')
# ('PDF:PomQuarkB', '3.', '0.', '10.')
# ('PDF:PomQuarkFrac', '0.2', '0.', '1.')
# ('PDF:PomStrangeSupp', '0.5', '0.', '1.')
# ('PDF:PomRescale', '1.0', '0.5', '5.0')
# ('PDF:PomHixSupp', '0.', '0.', '10.')
# ('PDF:gammaFluxApprox2bMin', '7.336', '0.0', '')
# ('PDF:gammaFluxApprox2mBeam', '0.9314', '0.0', '')
# ('PDF:gammaFluxApprox2xPow', '1.15', '0.0', '')
# ('PDF:gammaFluxApprox2xCut', '0.01', '0.0', '')
# ParticleData.html
# ('ParticleData:maxEnhanceBW', '2.5', '1.', '5.')
# ('ParticleData:mdRun', '0.006', '0.003', '0.008')
# ('ParticleData:muRun', '0.003', '0.001', '0.006')
# ('ParticleData:msRun', '0.095', '0.060', '0.150')
# ('ParticleData:mcRun', '1.25', '1.00', '1.50')
# ('ParticleData:mbRun', '4.20', '4.00', '4.50')
# ('ParticleData:mtRun', '165.0', '150.0', '175.0')
# ('ParticleData:alphaSvalueMRun', '0.125', '0.10', '0.20')
# ParticleDecays.html
# ('ParticleDecays:tau0Max', '10.', '0.', '')
# ('ParticleDecays:tauMax', '10.', '0.', '')
# ('ParticleDecays:rMax', '10.', '0.', '')
# ('ParticleDecays:xyMax', '10.', '0.', '')
# ('ParticleDecays:zMax', '10.', '0.', '')
# ('ParticleDecays:xBdMix', '0.776', '0.74', '0.81')
# ('ParticleDecays:xBsMix', '26.05', '22.0', '30.0')
# ('TauDecays:tauPolarization', '0', '-1.', '1.')
# ('TauDecays:mMinForZ', '-1', '', '')
# ('ParticleDecays:mSafety', '0.0005', '0.', '0.01')
# ('ParticleDecays:sigmaSoft', '0.5', '0.2', '2.')
# ('ParticleDecays:multIncrease', '4.', '2.', '6.')
# ('ParticleDecays:multIncreaseWeak', '2.5', '1.', '4.')
# ('ParticleDecays:multRefMass', '0.7', '0.2', '2.0')
# ('ParticleDecays:multGoffset', '0.5', '0.0', '2.0')
# ('ParticleDecays:colRearrange', '0.5', '0.', '1.0')
# PartonVertexInformation.html
# ('PartonVertex:phiAsym', '0.', '-0.9', '0.9')
# ('PartonVertex:ProtonRadius', '0.85', '0.', '10.')
# ('PartonVertex:EmissionWidth', '0.1', '0.', '10.')
# ('PartonVertex:pTmin', '0.2', '0.05', '1.')
# PhaseSpaceCuts.html
# ('PhaseSpace:mHatMin', '4.', '0.', '')
# ('PhaseSpace:mHatMax', '-1.', '', '')
# ('PhaseSpace:pTHatMin', '0.', '0.', '')
# ('PhaseSpace:pTHatMax', '-1.', '', '')
# ('PhaseSpace:pTHatMinDiverge', '1.', '0.5', '')
# ('PhaseSpace:minWidthBreitWigners', '0.01', '1e-6', '')
# ('PhaseSpace:minWidthNarrowBW', '1e-6', '1e-10', '')
# ('PhaseSpace:Q2Min', '0.0', '0.0', '')
# ('PhaseSpace:pTHat3Min', '10.', '0.', '')
# ('PhaseSpace:pTHat3Max', '-1.', '', '')
# ('PhaseSpace:pTHat5Min', '10.', '0.', '')
# ('PhaseSpace:pTHat5Max', '-1.', '', '')
# ('PhaseSpace:RsepMin', '1.', '', '')
# ('PhaseSpace:bias2SelectionPow', '4.', '0.', '10.')
# ('PhaseSpace:bias2SelectionRef', '10.', '1.', '')
# Photoproduction.html
# ('PhotonPhoton:ecmRef', '100.0', '1.', '')
# ('PhotonPhoton:pT0Ref', '1.52', '0.5', '10.0')
# ('PhotonPhoton:ecmPow', '0.413', '0.0', '0.5')
# ('PhotonPhoton:pTmin', '0.2', '0.1', '10.0')
# ('Photon:Q2max', '1.0', '', '2.0')
# ('Photon:Wmin', '10.0', '5.0', '')
# ('Photon:Wmax', '-1.0', '', '')
# ('Photon:thetaAMax', '-1.0', '', '3.141593')
# ('Photon:thetaBMax', '-1.0', '', '3.141593')
# QCDLowEnergyProcesses.html
# ('LowEnergyQCD:probDoubleAnnihilation', '0.2', '0.', '1.0')
# ('LowEnergyQCD:sEffAQM', '0.6', '0.', '1.0')
# ('LowEnergyQCD:cEffAQM', '0.2', '0.', '1.0')
# ('LowEnergyQCD:bEffAQM', '0.07', '0.', '1.0')
# RHadrons.html
# ('RHadrons:maxWidth', '0.2', '0.0', '1.0')
# ('RHadrons:probGluinoball', '0.1', '0.0', '1.0')
# ('RHadrons:mOffsetCloud', '0.2', '0.0', '')
# ('RHadrons:mCollapse', '1.0', '0.0', '')
# ('RHadrons:diquarkSpin1', '0.5', '0.0', '1.0')
# ResonanceDecays.html
# ('ResonanceWidths:minWidth', '1.97e-19', '1e-30', '')
# ('ResonanceWidths:minThreshold', '0.1', '0.01', '')
# RopeHadronization.html
# ('Ropewalk:r0', '0.5', '0.', '10.')
# ('Ropewalk:m0', '0.2', '0.01', '5.0')
# ('Ropewalk:rCutOff', '6.0', '0.', '100.')
# ('Ropewalk:gAmplitude', '5.0', '0.', '100.')
# ('Ropewalk:gExponent', '1.0', '0.', '100.')
# ('Ropewalk:deltay', '0.2', '0.01', '10.')
# ('Ropewalk:tShove', '1.0', '0.', '100.')
# ('Ropewalk:deltat', '0.1', '0.01', '100.0')
# ('Ropewalk:tInit', '1.5', '0.', '100.')
# ('Ropewalk:pTcut', '2.0', '0.', '1000.')
# ('Ropewalk:beta', '0.2', '0.', '1.0')
# ('Ropewalk:stringProtonRatio', '0.2', '0.', '10.0')
# ('Ropewalk:rapiditySpan', '0.5', '0.', '10.0')
# ('Ropewalk:presetKappa', '0.', '0.', '100.0')
# ('StringFlav:kappa', '0.2', '0.0', '10.')
# SUSYLesHouchesAccord.html
# ('SLHA:minMassSM', '100.0', '', '')
# StandardModelParameters.html
# ('StandardModel:alphaEM0', '0.00729735', '0.0072973', '0.0072974')
# ('StandardModel:alphaEMmZ', '0.00781751', '0.00780', '0.00783')
# ('StandardModel:sin2thetaW', '0.2312', '0.225', '0.240')
# ('StandardModel:sin2thetaWbar', '0.2315', '0.225', '0.240')
# ('StandardModel:GF', '1.16637e-5', '1.0e-5', '1.3e-5')
# TotalCrossSections.html
# ('SigmaDiffractive:PomFluxEpsilon', '0.085', '0.02', '0.15')
# ('SigmaDiffractive:PomFluxAlphaPrime', '0.25', '0.05', '0.4')
# ('SigmaDiffractive:PomFluxB0', '5.5', '0.5', '500.')
# ('SigmaDiffractive:OwnbMinDD', '1.', '0.5', '5.')
# ('SigmaDiffractive:Ownygap', '2.', '0.1', '')
# ('SigmaDiffractive:Ownypow', '5.', '0.5', '')
# ('SigmaDiffractive:OwnmMinCD', '1.', '0.5', '')
# ('SigmaDiffractive:mMin', '0.28', '0.0', '')
# ('SigmaDiffractive:lowMEnhance', '2.0', '0.0', '')
# ('SigmaDiffractive:mResMax', '1.062', '0.0', '')
# ('SigmaDiffractive:mMinCD', '1.', '0.5', '')
# ('SigmaDiffractive:maxXB', '65.', '0.', '')
# ('SigmaDiffractive:maxAX', '65.', '0.', '')
# ('SigmaDiffractive:maxXX', '65.', '0.', '')
# ('SigmaDiffractive:maxAXB', '3.', '0.', '')
# ('SigmaDiffractive:SaSepsilon', '0.0', '-0.2', '0.2')
# ('SigmaDiffractive:MBRepsilon', '0.104', '0.02', '0.15')
# ('SigmaDiffractive:MBRalpha', '0.25', '0.1', '0.4')
# ('SigmaDiffractive:MBRbeta0', '6.566', '0.0', '10.0')
# ('SigmaDiffractive:MBRsigma0', '2.82', '0.0', '5.0')
# ('SigmaDiffractive:MBRm2Min', '1.5', '0.0', '3.0')
# ('SigmaDiffractive:MBRdyminSDflux', '2.3', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminDDflux', '2.3', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminCDflux', '2.3', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminSD', '2.0', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminDD', '2.0', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminCD', '2.0', '0.0', '5.0')
# ('SigmaDiffractive:MBRdyminSigSD', '0.5', '0.001', '5.0')
# ('SigmaDiffractive:MBRdyminSigDD', '0.5', '0.001', '5.0')
# ('SigmaDiffractive:MBRdyminSigCD', '0.5', '0.001', '5.0')
# ('SigmaDiffractive:ABMSTmultSD', '1.', '0.01', '')
# ('SigmaDiffractive:ABMSTpowSD', '0.0', '0.0', '0.25')
# ('SigmaDiffractive:ABMSTmultDD', '1.', '0.01', '')
# ('SigmaDiffractive:ABMSTpowDD', '0.1', '0.0', '0.25')
# ('SigmaDiffractive:ABMSTmultCD', '1.', '0.01', '')
# ('SigmaDiffractive:ABMSTpowCD', '0.1', '0.0', '0.25')
# ('SigmaDiffractive:ABMSTmMinCD', '1.', '0.5', '')
# ('SigmaDiffractive:ABMSTygap', '2.', '0.1', '')
# ('SigmaDiffractive:ABMSTypow', '5.', '0.5', '')
# ('SigmaDiffractive:ABMSTbMinSD', '2.', '', '')
# ('SigmaDiffractive:ABMSTbMinDD', '2.', '', '')
# ('SigmaDiffractive:ABMSTbMinCD', '2.', '', '')
# ('SigmaElastic:tAbsMin', '5e-5', '1e-10', '1e-3')
# ('SigmaElastic:lambda', '0.71', '0.1', '2.')
# ('SigmaElastic:phaseConst', '0.577', '', '')
# ('SigmaCombined:eMinHigh', '6.', '5.', '20.')
# ('SigmaCombined:deltaEHigh', '8.', '0.', '20.')
# Vincia.html
# ('Vincia:sectorDamp', '1.0', '0.0', '1.0')
# ('Vincia:pTmaxFudge', '1.0', '0.1', '10.0')
# ('Vincia:pTmaxFudgeMPI', '1.0', '0.1', '10.0')
# ('Vincia:enhanceFacAll', '1.0', '0.01', '100.0')
# ('Vincia:enhanceFacBottom', '1.0', '1.0', '100.0')
# ('Vincia:enhanceFacCharm', '1.0', '1.0', '100.0')
# ('Vincia:enhanceCutoff', '10.0', '0.0', '1000.0')
# ('Vincia:octetPartitioning', '0.0', '0.0', '1.0')
# ('Vincia:deadZoneAvoidance', '0.0001', '0.0', '1.0')
# VinciaEW.html
# ('Vincia:alphaEM0', '0.00729735', '0.0072973', '0.0072974')
# ('Vincia:alphaEMmZ', '0.00781751', '0.00780', '0.00783')
# ('Vincia:QminChgQ', '0.5', '0.1', '2.0')
# ('Vincia:QminChgL', '1e-6', '1e-10', '2.0')
# ('Vincia:mMaxGamma', '10.', '0.001', '5000.0')
# ('Vincia:EWScale', '100.', '80.', '175.')
# ('Vincia:EWoverlapVetoDeltaR', '0.6', '0.1', '')
# ('Vincia:EWheadroomF', '1.1', '1.', '2.')
# ('Vincia:EWheadroomI', '3', '1.', '5.')
# VinciaQCD.html
# ('Vincia:alphaSvalue', '0.118', '0.06', '2.0')
# ('Vincia:alphaSmuFreeze', '0.75', '0.0', '10.0')
# ('Vincia:alphaSmax', '2.0', '0.1', '10.0')
# ('Vincia:renormMultFacEmitF', '0.66', '0.1', '10.0')
# ('Vincia:renormMultFacSplitF', '0.8', '0.1', '10.0')
# ('Vincia:renormMultFacEmitI', '0.66', '0.1', '10.0')
# ('Vincia:renormMultFacSplitI', '0.5', '0.1', '10.0')
# ('Vincia:renormMultFacConvI', '0.5', '0.1', '10.0')
# ('Vincia:QQemitII:chargeFactor', '2.66666667', '', '')
# ('Vincia:GQemitII:chargeFactor', '2.83333333', '', '')
# ('Vincia:GGemitII:chargeFactor', '3.0', '', '')
# ('Vincia:QXSplitII:chargeFactor', '1.0', '', '')
# ('Vincia:GXConvII:chargeFactor', '2.66666667', '', '')
# ('Vincia:QQemitIF:chargeFactor', '2.66666667', '', '')
# ('Vincia:GQemitIF:chargeFactor', '2.83333333', '', '')
# ('Vincia:QGemitIF:chargeFactor', '2.83333333', '', '')
# ('Vincia:GGemitIF:chargeFactor', '3.0', '', '')
# ('Vincia:QXSplitIF:chargeFactor', '1.0', '', '')
# ('Vincia:GXConvIF:chargeFactor', '2.66666667', '', '')
# ('Vincia:XGSplitIF:chargeFactor', '1.0', '', '')
# ('Vincia:QQEmitFF:chargeFactor', '2.66666667', '', '')
# ('Vincia:QGEmitFF:chargeFactor', '2.85', '', '')
# ('Vincia:GGEmitFF:chargeFactor', '3.0', '', '')
# ('Vincia:QGSplitFF:chargeFactor', '1.0', '', '')
# ('Vincia:GGSplitFF:chargeFactor', '1.0', '', '')
# ('Vincia:GXSplitFF:chargeFactor', '1.0', '', '')
# ('Vincia:QQEmitRF:chargeFactor', '2.66666667', '', '')
# ('Vincia:QGEmitRF:chargeFactor', '2.85', '', '')
# ('Vincia:XGSplitRF:chargeFactor', '1.0', '', '')
# ('Vincia:cutoffScaleFF', '0.75', '0.1', '10.0')
# ('Vincia:cutoffScaleII', '1.25', '0.1', '10.0')
# ('Vincia:cutoffScaleIF', '1.5', '0.1', '10.0')
# ('Vincia:ThresholdMB', '4.8', '', '')
# ('Vincia:ThresholdMC', '1.5', '', '')
