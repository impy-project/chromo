# %%
import uproot
from impy.models import Pythia8
from impy.kinematics import CenterOfMass
from impy.constants import GeV, quarks_and_diquarks_and_gluons
import awkward as ak
import numpy as np
from particle import literals as lp

# %%
model = Pythia8(CenterOfMass(10 * GeV, "proton", "proton"), seed=1)
model.set_stable(lp.pi_0.pdgid, False)
# Out:
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.307      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Feb 2022  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 18 Oct 2022 at 18:25:21    |  |
#  |  |                                                                              |  |
#  |  |   Program documentation and an archive of historic versions is found on:     |  |
#  |  |                                                                              |  |
#  |  |                               https://pythia.org/                            |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is authored by a collaboration consisting of:                       |  |
#  |  |                                                                              |  |
#  |  |   Christian Bierlich, Nishita Desai, Leif Gellersen, Ilkka Helenius, Philip  |  |
#  |  |   Ilten, Leif Lönnblad, Stephen Mrenna, Stefan Prestel, Christian Preuss,    |  |
#  |  |   Torbjörn Sjöstrand, Peter Skands, Marius Utheim and Rob Verheyen.          |  |
#  |  |                                                                              |  |
#  |  |   The complete list of authors, including contact information and            |  |
#  |  |   affiliations, can be found on https://pythia.org/.                         |  |
#  |  |   Problems or bugs should be reported on email at authors@pythia.org.        |  |
#  |  |                                                                              |  |
#  |  |   The main program reference is 'An Introduction to PYTHIA 8.2',             |  |
#  |  |   T. Sjöstrand et al, Comput. Phys. Commun. 191 (2015) 159                   |  |
#  |  |   [arXiv:1410.3012 [hep-ph]]                                                 |  |
#  |  |                                                                              |  |
#  |  |   The main physics reference is the 'PYTHIA 6.4 Physics and Manual',         |  |
#  |  |   T. Sjöstrand, S. Mrenna and P. Skands, JHEP05 (2006) 026 [hep-ph/0603175]  |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is released under the GNU General Public Licence version 2 or later.|  |
#  |  |   Please respect the MCnet Guidelines for Event Generator Authors and Users. |  |
#  |  |                                                                              |  |
#  |  |   Disclaimer: this program comes without any guarantees.                     |  |
#  |  |   Beware of errors and use common sense when interpreting results.           |  |
#  |  |                                                                              |  |
#  |  |   Copyright (C) 2022 Torbjörn Sjöstrand                                      |  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  *------------------------------------------------------------------------------*  |
#  |                                                                                    |
#  *------------------------------------------------------------------------------------*
#
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 1.300e+04 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | non-diffractive                                101 |   5.642e+01 |
#  | A B -> X B single diffractive                  103 |   6.416e+00 |
#  | A B -> A X single diffractive                  104 |   6.416e+00 |
#  | A B -> X X double diffractive                  105 |   8.798e+00 |
#  | A B -> A X B central diffractive               106 |   0.000e+00 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    56.42 mb              |
#  |                                                                  |
#  |    pT0 =  2.60 gives sigmaInteraction =   318.00 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction XB for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.56 gives sigmaInteraction =    25.11 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.62 gives sigmaInteraction =    24.13 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.68 gives sigmaInteraction =    22.26 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.76 gives sigmaInteraction =    20.10 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.84 gives sigmaInteraction =    18.35 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.93 gives sigmaInteraction =    16.96 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.03 gives sigmaInteraction =    16.52 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.14 gives sigmaInteraction =    17.00 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    18.61 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.41 gives sigmaInteraction =    21.39 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.56 gives sigmaInteraction =    24.92 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.73 gives sigmaInteraction =    30.40 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.91 gives sigmaInteraction =    36.35 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.12 gives sigmaInteraction =    43.46 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.35 gives sigmaInteraction =    51.48 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    61.14 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#  PYTHIA Warning in MultipartonInteractions::init: maximum increased by factor 4.184
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AX for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.56 gives sigmaInteraction =    25.16 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.62 gives sigmaInteraction =    24.07 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.68 gives sigmaInteraction =    22.26 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.76 gives sigmaInteraction =    20.05 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.84 gives sigmaInteraction =    18.25 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.93 gives sigmaInteraction =    17.06 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.03 gives sigmaInteraction =    16.45 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.14 gives sigmaInteraction =    16.95 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    18.58 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.41 gives sigmaInteraction =    21.24 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.56 gives sigmaInteraction =    25.37 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.73 gives sigmaInteraction =    30.35 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.91 gives sigmaInteraction =    36.41 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.12 gives sigmaInteraction =    43.83 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.35 gives sigmaInteraction =    51.90 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    61.50 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AXB for p+ on p+                                   |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.56 gives sigmaInteraction =     5.87 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =     8.81 mb: rejected    |
#  |    pT0 =  0.45 gives sigmaInteraction =    13.15 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.62 gives sigmaInteraction =     4.78 mb: rejected    |
#  |    pT0 =  0.56 gives sigmaInteraction =     6.98 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    10.29 mb: rejected    |
#  |    pT0 =  0.45 gives sigmaInteraction =    15.25 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.68 gives sigmaInteraction =     3.84 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =     5.49 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     7.92 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    11.48 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.76 gives sigmaInteraction =     3.14 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     4.38 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     6.16 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     8.68 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    12.30 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.84 gives sigmaInteraction =     2.71 mb: rejected    |
#  |    pT0 =  0.76 gives sigmaInteraction =     3.62 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     4.95 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     6.79 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     9.34 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    13.38 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.93 gives sigmaInteraction =     2.54 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     3.24 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     4.25 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     5.57 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     7.48 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =    10.25 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    14.24 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.03 gives sigmaInteraction =     2.54 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     3.16 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     3.96 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     5.00 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     6.41 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     8.36 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =    11.15 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.14 gives sigmaInteraction =     2.75 mb: rejected    |
#  |    pT0 =  1.03 gives sigmaInteraction =     3.30 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     4.00 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     4.84 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     6.02 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     7.50 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     9.53 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =    12.42 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =     3.08 mb: rejected    |
#  |    pT0 =  1.14 gives sigmaInteraction =     3.67 mb: rejected    |
#  |    pT0 =  1.03 gives sigmaInteraction =     4.33 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     5.09 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     6.07 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     7.33 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     8.87 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =    11.09 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.41 gives sigmaInteraction =     3.50 mb: rejected    |
#  |    pT0 =  1.27 gives sigmaInteraction =     4.14 mb: rejected    |
#  |    pT0 =  1.14 gives sigmaInteraction =     4.83 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =     5.60 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     6.56 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     7.61 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     8.98 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =    10.61 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =    12.90 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.56 gives sigmaInteraction =     4.07 mb: rejected    |
#  |    pT0 =  1.40 gives sigmaInteraction =     4.76 mb: rejected    |
#  |    pT0 =  1.26 gives sigmaInteraction =     5.54 mb: rejected    |
#  |    pT0 =  1.14 gives sigmaInteraction =     6.35 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =     7.29 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     8.23 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     9.59 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =    11.00 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.73 gives sigmaInteraction =     4.62 mb: rejected    |
#  |    pT0 =  1.55 gives sigmaInteraction =     5.48 mb: rejected    |
#  |    pT0 =  1.40 gives sigmaInteraction =     6.31 mb: rejected    |
#  |    pT0 =  1.26 gives sigmaInteraction =     7.23 mb: rejected    |
#  |    pT0 =  1.13 gives sigmaInteraction =     8.26 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =     9.38 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =    10.45 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =    11.93 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.91 gives sigmaInteraction =     5.28 mb: rejected    |
#  |    pT0 =  1.72 gives sigmaInteraction =     6.23 mb: rejected    |
#  |    pT0 =  1.55 gives sigmaInteraction =     7.17 mb: rejected    |
#  |    pT0 =  1.39 gives sigmaInteraction =     8.29 mb: rejected    |
#  |    pT0 =  1.26 gives sigmaInteraction =     9.41 mb: rejected    |
#  |    pT0 =  1.13 gives sigmaInteraction =    10.66 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =    11.86 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.12 gives sigmaInteraction =     5.98 mb: rejected    |
#  |    pT0 =  1.91 gives sigmaInteraction =     6.94 mb: rejected    |
#  |    pT0 =  1.72 gives sigmaInteraction =     8.23 mb: rejected    |
#  |    pT0 =  1.55 gives sigmaInteraction =     9.21 mb: rejected    |
#  |    pT0 =  1.39 gives sigmaInteraction =    10.61 mb: rejected    |
#  |    pT0 =  1.25 gives sigmaInteraction =    11.99 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.35 gives sigmaInteraction =     6.62 mb: rejected    |
#  |    pT0 =  2.12 gives sigmaInteraction =     7.71 mb: rejected    |
#  |    pT0 =  1.90 gives sigmaInteraction =     9.00 mb: rejected    |
#  |    pT0 =  1.71 gives sigmaInteraction =    10.27 mb: rejected    |
#  |    pT0 =  1.54 gives sigmaInteraction =    11.89 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =     7.22 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =     8.55 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =     9.88 mb: rejected    |
#  |    pT0 =  1.90 gives sigmaInteraction =    11.33 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | Beams:eCM                                     |                13000.000 |    14000.000         0.0             |
#  | Random:seed                                   |                        1 |           -1               900000000 |
#  | Random:setSeed                                |                       on |          off                         |
#  | SoftQCD:inelastic                             |                       on |          off                         |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------

# %%
nevents = 1000

def write(file, lengths, px, py, pz, m, vx, vy, vz, pid, status, par):
    b = np.sum(lengths)
    data = {
        "": ak.zip({
            "px": ak.unflatten(px[:b], lengths),
            "py": ak.unflatten(py[:b], lengths),
            "pz": ak.unflatten(pz[:b], lengths),
            "m": ak.unflatten(m[:b], lengths),
            "vx": ak.unflatten(vx[:b], lengths),
            "vy": ak.unflatten(vy[:b], lengths),
            "vz": ak.unflatten(vz[:b], lengths),
            "pid": ak.unflatten(pid[:b], lengths),
            "status": ak.unflatten(status[:b], lengths),
            "par": ak.unflatten(par[:b], lengths),
        }),
    }
    if "tree" in file:
        file["tree"].extend(data)
    else:
        file["tree"] = data

with uproot.recreate("output.root") as f:
    px = np.empty(100000)
    py = np.empty(100000)
    pz = np.empty(100000)
    m = np.empty(100000)
    vx = np.empty(100000)
    vy = np.empty(100000)
    vz = np.empty(100000)
    pid = np.empty(100000, np.int32)
    status = np.empty(100000, np.int32)
    par = np.empty(100000, np.int32)
    lengths = []
    b = 0
    for event in model(nevents):
        mask = True
        apid = np.abs(event.pid)
        for pdg in quarks_and_diquarks_and_gluons:
            mask &= apid != pdg
        mask[:2] = False
        out = event[mask]
        a = b
        b += len(out)
        lengths.append(b - a)
        px[a:b] = out.px
        py[a:b] = out.py
        pz[a:b] = out.pz
        m[a:b] = out.m
        vx[a:b] = out.vx
        vy[a:b] = out.vy
        vz[a:b] = out.vz
        pid[a:b] = out.pid
        status[a:b] = out.status
        par[a:b] = out.parents[:, 0] - 1
        if b > 50000:
            write(f, lengths, px, py, pz, m, vx, vy, vz, pid, status, par)
            lengths = []
            b = 0
    # write the rest
    if b:
        write(f, lengths, px, py, pz, m, vx, vy, vz, pid, status, par)
# Out:
#  Pythia::next(): 10000 events have been generated
#
#  Pythia::next(): 11000 events have been generated
#
#  Pythia::next(): 12000 events have been generated
#
#  Pythia::next(): 13000 events have been generated
#
#  Pythia::next(): 14000 events have been generated
#
#  Pythia::next(): 15000 events have been generated
#
#  Pythia::next(): 16000 events have been generated
#
#  Pythia::next(): 17000 events have been generated
#
#  Pythia::next(): 18000 events have been generated
#
#  Pythia::next(): 19000 events have been generated

# %%
import numpy as np
import uproot
from particle import literals as lp
import numba as nb


def pt_eta(px, py, pz):
    pt = np.sqrt(px ** 2 + py ** 2)
    eta = np.arcsinh(pz / pt)
    return pt, eta

photon_pid = int(lp.photon.pdgid)
pi0_pid = int(lp.pi_0.pdgid)


@nb.njit
def select_photons_from_pi0_decay(pid, par):
    result = np.zeros(len(pid), dtype="bool")
    for i, pidi in enumerate(pid):
        if pidi != photon_pid:
            continue
        if par[i] < 0:
            continue
        parent_pid = pid[par[i]]
        if parent_pid != pi0_pid:
            continue
        result[i] = True
    return result

with uproot.open("output.root") as f:
    tree = f["tree"]
    branches = ["px", "py", "pz", "m", "pid", "status", "par"]
    # loop over chunks in ROOT tree
    for chunk in tree.iterate(branches):
        # loop over individual events
        for px, py, pz, m, pid, sta, par in zip(*(chunk[k] for k in branches)):
            pt, eta = pt_eta(px, py, pz)

            print("all particles")
            print("  pseudorapidity", eta)
            print("  pdgid", pid)

            # select only long-lived particles
            mask = sta == 1
            print("long-lived particles")
            print("  pseudorapidity", eta[mask])
            print("  pdgid", pid[mask])

            # select only photons from pi0 decays
            mask = select_photons_from_pi0_decay(pid, par)
            print("  photons from pi0 decay")
            print("  pseudorapidity", eta[mask])

            break  # remove to not stop after first event
# Out:
# all particles
#   pseudorapidity [11.2, -11.2, 30.8, -0.626, 6.7, 7.32, 3.79, ... 1.61, 1.68, 4.69, 4.4, 4.76, 4.51]
#   pdgid [9902210, 2212, 2212, 990, 113, 211, -211, 213, ... 22, 22, 22, 22, 22, 22, 22, 22]
# long-lived particles
#   pseudorapidity [-11.2, 7.32, 3.79, 3.78, 3.95, 6.74, 6.39, ... 1.61, 1.68, 4.69, 4.4, 4.76, 4.51]
#   pdgid [2212, 211, -211, -211, -2112, -211, -211, 2212, ... 22, 22, 22, 22, 22, 22, 22, 22]
#   photons from pi0
#   pseudorapidity [3.06, 3.51, 1.61, 1.68, 4.69, 4.4, 4.76, 4.51]
